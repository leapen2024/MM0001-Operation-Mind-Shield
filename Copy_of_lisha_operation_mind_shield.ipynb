# %% [markdown]
# <a href="https://colab.research.google.com/github/leapen2024/MM0001-Operation-Mind-Shield/blob/main/Copy_of_lisha_operation_mind_shield.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operation Mind Shield: Decoding Alzheimer's
# #### **Full Name:** Lisha Eapen
# #### **Link to SDS Profile:** https://community.superdatascience.com/u/812508d9

# %% [markdown]
# thi is test file

# %%
import numpy
